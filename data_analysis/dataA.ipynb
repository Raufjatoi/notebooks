# %%
import pandas as p 

data = p.read_csv('data.csv')
data.head(3)
# Out:
#    Unnamed: 0  Price  Age     KM FuelType  HP  MetColor  Automatic    CC  \
# 0           1  13500   23  46986   Diesel  90         1          0  2000
# 1           2  13750   23  72937   Diesel  90         1          0  2000
# 2           3  13950   24  41711   Diesel  90         1          0  2000
#
#    Doors  Weight AutoType MetColorType
# 0      3    1165   Manual     Metcolor
# 1      3    1165   Manual     Metcolor
# 2      3    1165   Manual     Metcolor

# %%
data.tail(2)
# Out:
#       Unnamed: 0  Price  Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 1434        1435   7250   70  16916   Petrol   86         1          0  1300
# 1435        1436   6950   76      1   Petrol  110         0          0  1600
#
#       Doors  Weight AutoType MetColorType
# 1434      3    1015   Manual     Metcolor
# 1435      5    1114   Manual  NonMetcolor

# %%
data['Price'].head()
# Out:
# 0    13500
# 1    13750
# 2    13950
# 3    14950
# 4    13750
# Name: Price, dtype: int64

# %%
data.Price.tail()
# Out:
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, dtype: int64

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1436, step=1)

# %%
print(data.values)
data.value_counts
# Out:
# [[1 13500 23 ... 1165 'Manual' 'Metcolor']
#  [2 13750 23 ... 1165 'Manual' 'Metcolor']
#  [3 13950 24 ... 1165 'Manual' 'Metcolor']
#  ...
#  [1434 8500 71 ... 1015 'Manual' 'NonMetcolor']
#  [1435 7250 70 ... 1015 'Manual' 'Metcolor']
#  [1436 6950 76 ... 1114 'Manual' 'NonMetcolor']]
# <bound method DataFrame.value_counts of       Unnamed: 0  Price  Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              1  13500   23  46986   Diesel   90         1          0  2000
# 1              2  13750   23  72937   Diesel   90         1          0  2000
# 2              3  13950   24  41711   Diesel   90         1          0  2000
# 3              4  14950   26  48000   Diesel   90         0          0  2000
# 4              5  13750   30  38500   Diesel   90         0          0  2000
# ...          ...    ...  ...    ...      ...  ...       ...        ...   ...
# 1431        1432   7500   69  20544   Petrol   86         1          0  1300
# ...

# %%
data.plot()
# Out:
# <Axes: >

# %%
data['Price'].plot()
# Out:
# <Axes: >

# %%
data['KM'].plot()
# Out:
# <Axes: >

# %%
data['Price'].rolling(25).mean().plot()
# Out:
# <Axes: >
